# %% [markdown]
# ## Análise dos Microdados do ENEM

# %%
import pandas as pd

# %%
microdadosEnem = pd.read_csv("microdados_enem_2019/DADOS/MICRODADOS_ENEM_2019.csv", sep=";", encoding='ISO-8859-1')

# %%
microdadosEnem.head()
# Out:
#    NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0  190001595656    2019               13       M                1
# 1  190001421546    2019                8       M                1
# 2  190001133210    2019               13       F                1
# 3  190001199383    2019               10       F                1
# 4  190001237802    2019                7       F                1
#
#    TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ESCOLA  \
# 0            3                 1                1               11          1
# 1            1                 1                1                5          1
# 2            3                 1                1               13          1
# 3            1                 1                1                4          1
# 4            1                 1                1                4          1
#
#    ...  Q016  Q017  Q018 Q019  Q020 Q021  Q022  Q023  Q024  Q025
# ...

# %%
microdadosEnem
# Out:
#          NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0        190001595656    2019               13       M                1
# 1        190001421546    2019                8       M                1
# 2        190001133210    2019               13       F                1
# 3        190001199383    2019               10       F                1
# 4        190001237802    2019                7       F                1
# ...               ...     ...              ...     ...              ...
# 5095166  190006074437    2019               14       F                4
# 5095167  190005429225    2019                5       M                1
# 5095168  190006087652    2019                6       M                0
# 5095169  190006087653    2019                7       M                0
# 5095170  190006087654    2019                6       F                0
#
#          TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  \
# ...

# %%
#Nome das Colunas
microdadosEnem.columns.values
# Out:
# array(['NU_INSCRICAO', 'NU_ANO', 'TP_FAIXA_ETARIA', 'TP_SEXO',
#        'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_NACIONALIDADE',
#        'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO',
#        'IN_TREINEIRO', 'CO_MUNICIPIO_ESC', 'NO_MUNICIPIO_ESC',
#        'CO_UF_ESC', 'SG_UF_ESC', 'TP_DEPENDENCIA_ADM_ESC',
#        'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC', 'CO_MUNICIPIO_PROVA',
#        'NO_MUNICIPIO_PROVA', 'CO_UF_PROVA', 'SG_UF_PROVA',
#        'TP_PRESENCA_CN', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC',
#        'TP_PRESENCA_MT', 'CO_PROVA_CN', 'CO_PROVA_CH', 'CO_PROVA_LC',
#        'CO_PROVA_MT', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC',
#        'NU_NOTA_MT', 'TX_RESPOSTAS_CN', 'TX_RESPOSTAS_CH',
#        'TX_RESPOSTAS_LC', 'TX_RESPOSTAS_MT', 'TP_LINGUA',
#        'TX_GABARITO_CN', 'TX_GABARITO_CH', 'TX_GABARITO_LC',
#        'TX_GABARITO_MT', 'TP_STATUS_REDACAO', 'NU_NOTA_COMP1',
#        'NU_NOTA_COMP2', 'NU_NOTA_COMP3', 'NU_NOTA_COMP4', 'NU_NOTA_COMP5',
# ...

# %%
colunasSelecionadasEnem = ['CO_MUNICIPIO_ESC', 'NO_MUNICIPIO_ESC',
       'TP_FAIXA_ETARIA', 'TP_SEXO', 'TP_ESTADO_CIVIL', 'TP_COR_RACA',
       'TP_NACIONALIDADE', 'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA',
       'TP_ENSINO', 'IN_TREINEIRO', 'CO_UF_ESC', 'SG_UF_ESC', 'TP_DEPENDENCIA_ADM_ESC',
       'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC',
       'TP_PRESENCA_CN', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC',
       'TP_PRESENCA_MT', 'CO_PROVA_CN', 'CO_PROVA_CH', 'CO_PROVA_LC',
       'CO_PROVA_MT', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC',
       'NU_NOTA_MT', 'TP_LINGUA', 'TP_STATUS_REDACAO', 'NU_NOTA_COMP1',
       'NU_NOTA_COMP2', 'NU_NOTA_COMP3', 'NU_NOTA_COMP4', 'NU_NOTA_COMP5',
       'NU_NOTA_REDACAO']

# %%
microdadosEnemSelecionados = microdadosEnem.filter(items=colunasSelecionadasEnem)

# %%
microdadosEnemSelecionados.head()
# Out:
#    CO_MUNICIPIO_ESC NO_MUNICIPIO_ESC  TP_FAIXA_ETARIA TP_SEXO  \
# 0               NaN              NaN               13       M
# 1               NaN              NaN                8       M
# 2               NaN              NaN               13       F
# 3               NaN              NaN               10       F
# 4               NaN              NaN                7       F
#
#    TP_ESTADO_CIVIL  TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  \
# 0                1            3                 1                1
# 1                1            1                 1                1
# 2                1            3                 1                1
# 3                1            1                 1                1
# 4                1            1                 1                1
#
#    TP_ANO_CONCLUIU  TP_ESCOLA  ...  NU_NOTA_LC  NU_NOTA_MT  TP_LINGUA  \
# 0               11          1  ...         NaN         NaN          0
# ...

# %%
microdados100 = microdadosEnemSelecionados[0:100]

# %%
coluna_NO_MUNICIPIO_ESC = microdadosEnemSelecionados['NO_MUNICIPIO_ESC']
coluna_TP_FAIXA_ETARIA = microdadosEnemSelecionados['TP_FAIXA_ETARIA']
coluna_SG_UF_ESC = microdadosEnemSelecionados['SG_UF_ESC']
coluna_TP_DEPENDENCIA_ADM_ESC = microdadosEnemSelecionados['TP_DEPENDENCIA_ADM_ESC']
coluna_TP_SEXO = microdadosEnemSelecionados['TP_SEXO']

# %%
coluna_NO_MUNICIPIO_ESC
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#           ...
# 5095166    NaN
# 5095167    NaN
# 5095168    NaN
# 5095169    NaN
# 5095170    NaN
# Name: NO_MUNICIPIO_ESC, Length: 5095171, dtype: object

# %%
coluna_NO_MUNICIPIO_ESC.value_counts().sort_index()
# Out:
# Abadia de Goiás          79
# Abadia dos Dourados      18
# Abadiânia               102
# Abaetetuba             1121
# Abaeté                  104
#                        ...
# Áurea                    15
# Ângulo                   12
# Érico Cardoso            37
# Óbidos                  226
# Óleo                     29
# Name: NO_MUNICIPIO_ESC, Length: 5277, dtype: int64

# %%
coluna_TP_FAIXA_ETARIA.value_counts()
# Out:
# 3     864166
# 2     847284
# 4     577155
# 5     409378
# 11    403776
# 1     400661
# 6     290307
# 12    235044
# 7     233034
# 8     187679
# 13    158944
# 9     156259
# 10    128038
# 14     93328
# 15     55930
# 16     31186
# 17     14743
# 18      5623
# 19      1919
# 20       717
# Name: TP_FAIXA_ETARIA, dtype: int64

# %%
coluna_TP_FAIXA_ETARIA.hist(bins=30)
# Out:
# <AxesSubplot:>

# %%
coluna_SG_UF_ESC.value_counts()
# Out:
# SP    219424
# CE    112313
# MG    108173
# RJ     73085
# BA     70323
# PE     61506
# PR     52788
# PA     46740
# RS     46173
# MA     43496
# GO     35545
# SC     34646
# PB     26938
# AM     25817
# ES     25422
# PI     24145
# DF     21075
# RN     20349
# MT     18022
# AL     17551
# MS     15539
# SE     13494
# RO     12069
# TO      9087
# AP      6135
# AC      5330
# RR      2202
# Name: SG_UF_ESC, dtype: int64

# %%
coluna_SG_UF_ESC.hist(bins=27)
# Out:
# <AxesSubplot:>

# %%
coluna_TP_DEPENDENCIA_ADM_ESC.value_counts()
# Out:
# 2.0    924321
# 4.0    164329
# 1.0     49087
# 3.0      9650
# Name: TP_DEPENDENCIA_ADM_ESC, dtype: int64

# %%
distInEscPrivada = coluna_TP_DEPENDENCIA_ADM_ESC.value_counts()

# %%
distInEscPrivada
# Out:
# 2.0    924321
# 4.0    164329
# 1.0     49087
# 3.0      9650
# Name: TP_DEPENDENCIA_ADM_ESC, dtype: int64

# %%
percentInEscPrivada = [100*x/distInEscPrivada.sum() for x in distInEscPrivada]

# %%
percentInEscPrivada
# Out:
# [80.55878269494076, 14.32202038196354, 4.278155495922475, 0.8410414271732205]

# %%
distTpSexo = coluna_TP_SEXO.value_counts()

# %%
distTpSexo
# Out:
# F    3031760
# M    2063411
# Name: TP_SEXO, dtype: int64

# %%
percentTpSexo = [100*x/distTpSexo.sum() for x in distTpSexo]

# %%
percentTpSexo
# Out:
# [59.50261531948584, 40.49738468051416]
